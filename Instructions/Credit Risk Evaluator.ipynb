# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
train_df = pd.read_csv(Path('Resources/Generator/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/Generator/2020Q1loans.csv'))

# %%
train_df.head(10)
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0     7000.0    0.1894       256.38       MORTGAGE     75000.0
# 1    40000.0    0.1614       975.71       MORTGAGE    102000.0
# 2    11000.0    0.2055       294.81           RENT     45000.0
# 3     4000.0    0.1612       140.87       MORTGAGE     38000.0
# 4    14000.0    0.1797       505.93       MORTGAGE     43000.0
# 5     6000.0    0.0756       186.81       MORTGAGE     90500.0
# 6    10500.0    0.2250       293.00           RENT     32000.0
# 7    22000.0    0.0819       448.09       MORTGAGE     92000.0
# 8    10625.0    0.2055       284.76           RENT     54100.0
# 9    20000.0    0.2534       591.02            OWN     38000.0
#
#   verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0        Not Verified          n  28.62          0.0             2.0  ...
# 1     Source Verified          n  11.72          2.0             0.0  ...
# ...

# %%
train_df.target.value_counts()
# Out:
# low_risk     6090
# high_risk    6090
# Name: target, dtype: int64

# %%
# Convert categorical data to numeric and separate target feature for training data

# %%
# Convert categorical data to numeric
train_df = pd.get_dummies(train_df, columns=['home_ownership','verification_status','pymnt_plan','initial_list_status','application_type','hardship_flag', 'debt_settlement_flag','target'])
train_df
# Out:
#        loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0         7000.0    0.1894       256.38     75000.0  28.62          0.0
# 1        40000.0    0.1614       975.71    102000.0  11.72          2.0
# 2        11000.0    0.2055       294.81     45000.0  37.25          1.0
# 3         4000.0    0.1612       140.87     38000.0  42.89          1.0
# 4        14000.0    0.1797       505.93     43000.0  22.16          1.0
# ...          ...       ...          ...         ...    ...          ...
# 12175    19975.0    0.2565       801.09     28000.0  28.42          0.0
# 12176    15000.0    0.1774       540.34     50000.0  23.43          4.0
# 12177     3600.0    0.1862       131.28     60000.0  28.80          0.0
# 12178    15000.0    0.0881       475.68     62000.0  11.44          0.0
# 12179    15000.0    0.1774       540.34     54080.0  21.66          1.0
#
#        inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# ...

# %%
 # List dataframe data types
train_df.dtypes
# Out:
# loan_amnt                 float64
# int_rate                  float64
# installment               float64
# annual_inc                float64
# dti                       float64
#                            ...
# hardship_flag_Y             uint8
# debt_settlement_flag_N      uint8
# debt_settlement_flag_Y      uint8
# target_high_risk            uint8
# target_low_risk             uint8
# Length: 94, dtype: object

# %%
# train_df.to_csv('trainloans.csv', index=False)

# %%
# separate target feature for training data
X = train_df.drop(['target_high_risk'], axis=1)
y = train_df['target_high_risk']

# %%
 # Convert categorical data to numeric and separate target feature for testing data

# %%
test_df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    40000.0    0.1033       856.40           RENT    128700.0
# 1    24450.0    0.1430       572.72       MORTGAGE     44574.0
# 2    13500.0    0.1430       316.23            OWN     60000.0
# 3    10625.0    0.1774       268.31           RENT     60000.0
# 4     6375.0    0.1862       232.46           RENT     60000.0
#
#   verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0     Source Verified          n  12.47          0.0             1.0  ...
# 1        Not Verified          n  15.05          0.0             1.0  ...
# 2        Not Verified          n  28.72          0.0             0.0  ...
# 3            Verified          n  15.70          0.0             4.0  ...
# 4     Source Verified          n  35.50          0.0             0.0  ...
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# ...

# %%
# Convert categorical data to numeric
test_df = pd.get_dummies(test_df, columns=['home_ownership','verification_status','pymnt_plan','initial_list_status','application_type','hardship_flag', 'debt_settlement_flag','target'])
test_df
# Out:
#       loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0       40000.0    0.1033       856.40    128700.0  12.47          0.0
# 1       24450.0    0.1430       572.72     44574.0  15.05          0.0
# 2       13500.0    0.1430       316.23     60000.0  28.72          0.0
# 3       10625.0    0.1774       268.31     60000.0  15.70          0.0
# 4        6375.0    0.1862       232.46     60000.0  35.50          0.0
# ...         ...       ...          ...         ...    ...          ...
# 4697    30000.0    0.1240       673.42    140480.0  15.74          0.0
# 4698    24000.0    0.0756       747.22     50000.0  26.81          0.0
# 4699    10000.0    0.2305       387.36     33000.0  38.51          0.0
# 4700     8000.0    0.1862       205.86     38000.0  16.36          0.0
# 4701    30000.0    0.2055      1123.34    180000.0  12.06          0.0
#
#       inq_last_6mths  open_acc  pub_rec  revol_bal  ...  pymnt_plan_n  \
# ...

# %%
test_df.dtypes
# Out:
# loan_amnt                 float64
# int_rate                  float64
# installment               float64
# annual_inc                float64
# dti                       float64
#                            ...
# hardship_flag_N             uint8
# hardship_flag_Y             uint8
# debt_settlement_flag_N      uint8
# target_high_risk            uint8
# target_low_risk             uint8
# Length: 93, dtype: object

# %%
# test_df.to_csv('testloans.csv', index=False)

# %% [markdown]
# I believe Random Forest Classifier will work better because we are predicting whether a loan will become high risk or not and not a sliding scale. Plus I read that Logistical models like less noise - which I assume with 94 columns, their is a lot of noise in this data set.

# %%
# separate target feature for training data
X = test_df.drop(['target_high_risk'], axis=1)
y = test_df['target_high_risk']

# %%
# add missing dummy variables to testing set

test_df.insert(88, 'debt_settlement_flag_Y', '0')

# %%
test_df.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0    40000.0    0.1033       856.40    128700.0  12.47          0.0
# 1    24450.0    0.1430       572.72     44574.0  15.05          0.0
# 2    13500.0    0.1430       316.23     60000.0  28.72          0.0
# 3    10625.0    0.1774       268.31     60000.0  15.70          0.0
# 4     6375.0    0.1862       232.46     60000.0  35.50          0.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  ...  initial_list_status_f  \
# 0             1.0       8.0      0.0    38113.0  ...                      0
# 1             1.0       6.0      0.0     1665.0  ...                      0
# 2             0.0       8.0      0.0    13857.0  ...                      0
# 3             4.0      17.0      0.0     6216.0  ...                      0
# 4             0.0      13.0      0.0    12681.0  ...                      0
#
#    initial_list_status_w  application_type_Individual  \
# ...

# %%
X_train = train_df.drop (columns = ['target_high_risk','target_low_risk'])
y_train = train_df['target_high_risk']
y_train.value_counts()
# Out:
# 0    6090
# 1    6090
# Name: target_high_risk, dtype: int64

# %%
X_test = test_df.drop (columns = ['target_high_risk','target_low_risk'])
y_test = test_df['target_high_risk']
y_test.value_counts()
# Out:
# 0    2351
# 1    2351
# Name: target_high_risk, dtype: int64

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state=1, max_iter=10000)
classifier
# Out:
# LogisticRegression(max_iter=10000, random_state=1)

# %%
classifier.fit(X_train, y_train)
classifier.score(X_test,y_test)
# Out:
# 0.5652913653764355

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train, y_train)
print(f'Training Score: {clf.score(X_train, y_train)}')
print(f'Testing Score: {clf.score(X_test, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.5829434283283709

# %%
# Scale the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train the Logistic Regression model on the scaled data and print the model score
classifier_scaled = LogisticRegression(random_state=1, max_iter = 10000)
classifier_scaled
# Out:
# LogisticRegression(max_iter=10000, random_state=1)

# %%
classifier_scaled.fit(X_train_scaled, y_train)
classifier_scaled.score(X_test_scaled,y_test)
# Out:
# 0.5370055295618885

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train_scaled, y_train)
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.582092726499362
